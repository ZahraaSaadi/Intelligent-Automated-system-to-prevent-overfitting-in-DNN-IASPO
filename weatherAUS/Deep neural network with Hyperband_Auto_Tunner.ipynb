# %%
# !pip install keras-tuner --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.0-py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.3/167.3 KB 5.6 MB/s eta 0:00:00
# Collecting kt-legacy
#   Downloading kt_legacy-1.0.4-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (7.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (23.0)
# Requirement already satisfied: tensorflow>=2.0 in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.8/dist-packages (from keras-tuner) (2.25.1)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (4.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.51.3)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.4.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.15.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.3.0)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.11.2)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (15.0.6.1)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (23.1.21)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.19.6)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (2.2.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.22.4)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (3.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow>=2.0->keras-tuner) (57.4.0)
# Requirement already satisfied: pygments in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.6.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.4.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (4.8.0)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (5.7.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from ipython->keras-tuner) (2.0.10)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 36.9 MB/s eta 0:00:00
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests->keras-tuner) (1.26.14)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow>=2.0->keras-tuner) (0.38.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.8/dist-packages (from jedi>=0.10->ipython->keras-tuner) (0.8.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.8/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->ipython->keras-tuner) (0.2.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.16.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.4.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.2.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.6.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.8/dist-packages (from pexpect->ipython->keras-tuner) (0.7.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (5.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (6.0.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.8/dist-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.15.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow>=2.0->keras-tuner) (3.2.2)
# Installing collected packages: kt-legacy, jedi, keras-tuner
# Successfully installed jedi-0.18.2 keras-tuner-1.3.0 kt-legacy-1.0.4

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d jsphyg/weather-dataset-rattle-package
# Out:
# Downloading weather-dataset-rattle-package.zip to /content
#   0% 0.00/3.83M [00:00<?, ?B/s]
# 100% 3.83M/3.83M [00:00<00:00, 192MB/s]

# %%
! unzip /content/weather-dataset-rattle-package.zip
# Out:
# Archive:  /content/weather-dataset-rattle-package.zip
#   inflating: weatherAUS.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import tqdm 
import seaborn as sn
from sklearn import metrics, preprocessing, model_selection
import keras_tuner as kt

# %% [markdown]
# # Read the Data

# %%
dataset = pd.read_csv('/content/weatherAUS.csv')
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 145455       NaN           E           31.0         SE  ...        51.0
# 145456       NaN         NNW           22.0         SE  ...        56.0
# 145457       NaN           N           37.0         SE  ...        53.0
# 145458       NaN          SE           28.0        SSE  ...        51.0
# 145459       NaN         NaN            NaN        ESE  ...        62.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 145455         24.0       1024.6       1020.3       NaN       NaN     10.1
# 145456         21.0       1023.5       1019.1       NaN       NaN     10.9
# 145457         24.0       1021.0       1016.8       NaN       NaN     12.5
# 145458         24.0       1019.4       1016.5       3.0       2.0     15.1
# 145459         36.0       1020.2       1017.9       8.0       8.0     15.0
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 145455     22.4         No            No
# 145456     24.5         No            No
# 145457     26.1         No            No
# 145458     26.0         No            No
# 145459     20.9         No           NaN
#
# [145460 rows x 23 columns]

# %%
# show the dataset information 
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
#  16  Pressure3pm    130432 non-null  float64
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  float64
#  20  Temp3pm        141851 non-null  float64
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.5+ MB

# %% [markdown]
# # Preprocessing the Dataset

# %%
# drop the na values 
dataset.dropna(inplace=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
#  17  Cloud9am       56420 non-null  float64
#  18  Cloud3pm       56420 non-null  float64
#  19  Temp9am        56420 non-null  float64
#  20  Temp3pm        56420 non-null  float64
#  21  RainToday      56420 non-null  object
#  22  RainTomorrow   56420 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 10.3+ MB

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 6054    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 6049        12.3         SSW           48.0        ENE  ...        20.0
# 6050        13.0           S           37.0        SSE  ...        30.0
# 6052        10.6         NNE           46.0        NNE  ...        42.0
# 6053        12.2         WNW           31.0        WNW  ...        37.0
# 6054         8.4         WNW           35.0         NW  ...        19.0
# ...          ...         ...            ...        ...  ...         ...
# 142298      11.0         ENE           35.0         SE  ...        63.0
# 142299       8.6           E           37.0         SE  ...        56.0
# 142300      11.0           E           33.0          E  ...        46.0
# 142301      10.6         ESE           26.0         SE  ...        62.0
# 142302      10.7         ENE           30.0        ENE  ...        73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 6049           13.0       1006.3       1004.4       2.0       5.0     26.6
# 6050            8.0       1012.9       1012.1       1.0       1.0     20.3
# 6052           22.0       1012.3       1009.2       1.0       6.0     28.7
# 6053           22.0       1012.7       1009.1       1.0       5.0     29.1
# 6054           15.0       1010.7       1007.4       1.0       6.0     33.6
# ...             ...          ...          ...       ...       ...      ...
# 142298         32.0       1013.9       1010.5       0.0       1.0     24.5
# 142299         28.0       1014.6       1011.2       7.0       0.0     24.8
# 142300         23.0       1015.3       1011.8       0.0       0.0     24.8
# 142301         58.0       1014.9       1010.7       1.0       1.0     24.8
# 142302         32.0       1013.9       1009.7       6.0       5.0     25.4
#
#         Temp3pm  RainToday  RainTomorrow
# 6049       33.4         No            No
# 6050       27.0         No            No
# 6052       34.9         No            No
# 6053       35.6         No            No
# 6054       37.6         No            No
# ...         ...        ...           ...
# 142298     32.3         No            No
# 142299     32.0         No            No
# 142300     32.1         No            No
# 142301     29.2         No            No
# 142302     31.0         No            No
#
# [56420 rows x 23 columns]

# %%
# plot the histogram 
dataset.hist(figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'MinTemp'}>,
#         <AxesSubplot:title={'center':'MaxTemp'}>,
#         <AxesSubplot:title={'center':'Rainfall'}>,
#         <AxesSubplot:title={'center':'Evaporation'}>],
#        [<AxesSubplot:title={'center':'Sunshine'}>,
#         <AxesSubplot:title={'center':'WindGustSpeed'}>,
#         <AxesSubplot:title={'center':'WindSpeed9am'}>,
#         <AxesSubplot:title={'center':'WindSpeed3pm'}>],
#        [<AxesSubplot:title={'center':'Humidity9am'}>,
#         <AxesSubplot:title={'center':'Humidity3pm'}>,
#         <AxesSubplot:title={'center':'Pressure9am'}>,
#         <AxesSubplot:title={'center':'Pressure3pm'}>],
#        [<AxesSubplot:title={'center':'Cloud9am'}>,
#         <AxesSubplot:title={'center':'Cloud3pm'}>,
#         <AxesSubplot:title={'center':'Temp9am'}>,
#         <AxesSubplot:title={'center':'Temp3pm'}>]], dtype=object)

# %%
dataset.describe()
# Out:
#             MinTemp       MaxTemp      Rainfall   Evaporation      Sunshine  \
# count  56420.000000  56420.000000  56420.000000  56420.000000  56420.000000
# mean      13.464770     24.219206      2.130397      5.503135      7.735626
# std        6.416689      6.970676      7.014822      3.696282      3.758153
# min       -6.700000      4.100000      0.000000      0.000000      0.000000
# 25%        8.600000     18.700000      0.000000      2.800000      5.000000
# 50%       13.200000     23.900000      0.000000      5.000000      8.600000
# 75%       18.400000     29.700000      0.600000      7.400000     10.700000
# max       31.400000     48.100000    206.200000     81.200000     14.500000
#
#        WindGustSpeed  WindSpeed9am  WindSpeed3pm   Humidity9am   Humidity3pm  \
# count   56420.000000  56420.000000  56420.000000  56420.000000  56420.000000
# mean       40.877366     15.667228     19.786778     65.874123     49.601985
# std        13.335232      8.317005      8.510180     18.513289     20.197040
# min         9.000000      2.000000      2.000000      0.000000      0.000000
# 25%        31.000000      9.000000     13.000000     55.000000     35.000000
# 50%        39.000000     15.000000     19.000000     67.000000     50.000000
# 75%        48.000000     20.000000     26.000000     79.000000     63.000000
# max       124.000000     67.000000     76.000000    100.000000    100.000000
#
#         Pressure9am   Pressure3pm      Cloud9am      Cloud3pm       Temp9am  \
# count  56420.000000  56420.000000  56420.000000  56420.000000  56420.000000
# mean    1017.239505   1014.795580      4.241705      4.326515     18.204961
# std        6.909357      6.870892      2.797162      2.647251      6.567991
# min      980.500000    977.100000      0.000000      0.000000     -0.700000
# 25%     1012.700000   1010.100000      1.000000      2.000000     13.100000
# 50%     1017.200000   1014.700000      5.000000      5.000000     17.800000
# 75%     1021.800000   1019.400000      7.000000      7.000000     23.300000
# max     1040.400000   1038.900000      8.000000      9.000000     39.400000
#
#             Temp3pm
# count  56420.000000
# mean      22.710333
# std        6.836543
# min        3.700000
# 25%       17.400000
# 50%       22.400000
# 75%       27.900000
# max       46.100000

# %%
dataset
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 6049    2009-01-01    Cobar     17.9     35.2       0.0         12.0
# 6050    2009-01-02    Cobar     18.4     28.9       0.0         14.8
# 6052    2009-01-04    Cobar     19.4     37.6       0.0         10.8
# 6053    2009-01-05    Cobar     21.9     38.4       0.0         11.4
# 6054    2009-01-06    Cobar     24.2     41.0       0.0         11.2
# ...            ...      ...      ...      ...       ...          ...
# 142298  2017-06-20   Darwin     19.3     33.4       0.0          6.0
# 142299  2017-06-21   Darwin     21.2     32.6       0.0          7.6
# 142300  2017-06-22   Darwin     20.7     32.8       0.0          5.6
# 142301  2017-06-23   Darwin     19.5     31.8       0.0          6.2
# 142302  2017-06-24   Darwin     20.2     31.7       0.0          5.6
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 6049        12.3         SSW           48.0        ENE  ...        20.0
# 6050        13.0           S           37.0        SSE  ...        30.0
# 6052        10.6         NNE           46.0        NNE  ...        42.0
# 6053        12.2         WNW           31.0        WNW  ...        37.0
# 6054         8.4         WNW           35.0         NW  ...        19.0
# ...          ...         ...            ...        ...  ...         ...
# 142298      11.0         ENE           35.0         SE  ...        63.0
# 142299       8.6           E           37.0         SE  ...        56.0
# 142300      11.0           E           33.0          E  ...        46.0
# 142301      10.6         ESE           26.0         SE  ...        62.0
# 142302      10.7         ENE           30.0        ENE  ...        73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 6049           13.0       1006.3       1004.4       2.0       5.0     26.6
# 6050            8.0       1012.9       1012.1       1.0       1.0     20.3
# 6052           22.0       1012.3       1009.2       1.0       6.0     28.7
# 6053           22.0       1012.7       1009.1       1.0       5.0     29.1
# 6054           15.0       1010.7       1007.4       1.0       6.0     33.6
# ...             ...          ...          ...       ...       ...      ...
# 142298         32.0       1013.9       1010.5       0.0       1.0     24.5
# 142299         28.0       1014.6       1011.2       7.0       0.0     24.8
# 142300         23.0       1015.3       1011.8       0.0       0.0     24.8
# 142301         58.0       1014.9       1010.7       1.0       1.0     24.8
# 142302         32.0       1013.9       1009.7       6.0       5.0     25.4
#
#         Temp3pm  RainToday  RainTomorrow
# 6049       33.4         No            No
# 6050       27.0         No            No
# 6052       34.9         No            No
# 6053       35.6         No            No
# 6054       37.6         No            No
# ...         ...        ...           ...
# 142298     32.3         No            No
# 142299     32.0         No            No
# 142300     32.1         No            No
# 142301     29.2         No            No
# 142302     31.0         No            No
#
# [56420 rows x 23 columns]

# %%
# drop out the Date	Location columns 
dataset.drop(columns=['Location','Date'],inplace=True)

# %%
dataset
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6049       17.9     35.2       0.0         12.0      12.3         SSW
# 6050       18.4     28.9       0.0         14.8      13.0           S
# 6052       19.4     37.6       0.0         10.8      10.6         NNE
# 6053       21.9     38.4       0.0         11.4      12.2         WNW
# 6054       24.2     41.0       0.0         11.2       8.4         WNW
# ...         ...      ...       ...          ...       ...         ...
# 142298     19.3     33.4       0.0          6.0      11.0         ENE
# 142299     21.2     32.6       0.0          7.6       8.6           E
# 142300     20.7     32.8       0.0          5.6      11.0           E
# 142301     19.5     31.8       0.0          6.2      10.6         ESE
# 142302     20.2     31.7       0.0          5.6      10.7         ENE
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 6049             48.0        ENE         SW           6.0  ...         20.0
# 6050             37.0        SSE        SSE          19.0  ...         30.0
# 6052             46.0        NNE        NNW          30.0  ...         42.0
# 6053             31.0        WNW        WSW           6.0  ...         37.0
# 6054             35.0         NW        WNW          17.0  ...         19.0
# ...               ...        ...        ...           ...  ...          ...
# 142298           35.0         SE         NE           9.0  ...         63.0
# 142299           37.0         SE         SE          13.0  ...         56.0
# 142300           33.0          E          W          17.0  ...         46.0
# 142301           26.0         SE        NNW           9.0  ...         62.0
# 142302           30.0        ENE        NNW          15.0  ...         73.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 6049           13.0       1006.3       1004.4       2.0       5.0     26.6
# 6050            8.0       1012.9       1012.1       1.0       1.0     20.3
# 6052           22.0       1012.3       1009.2       1.0       6.0     28.7
# 6053           22.0       1012.7       1009.1       1.0       5.0     29.1
# 6054           15.0       1010.7       1007.4       1.0       6.0     33.6
# ...             ...          ...          ...       ...       ...      ...
# 142298         32.0       1013.9       1010.5       0.0       1.0     24.5
# 142299         28.0       1014.6       1011.2       7.0       0.0     24.8
# 142300         23.0       1015.3       1011.8       0.0       0.0     24.8
# 142301         58.0       1014.9       1010.7       1.0       1.0     24.8
# 142302         32.0       1013.9       1009.7       6.0       5.0     25.4
#
#         Temp3pm  RainToday RainTomorrow
# 6049       33.4         No           No
# 6050       27.0         No           No
# 6052       34.9         No           No
# 6053       35.6         No           No
# 6054       37.6         No           No
# ...         ...        ...          ...
# 142298     32.3         No           No
# 142299     32.0         No           No
# 142300     32.1         No           No
# 142301     29.2         No           No
# 142302     31.0         No           No
#
# [56420 rows x 21 columns]

# %%
dataset .iloc[0]
# Out:
# MinTemp            17.9
# MaxTemp            35.2
# Rainfall            0.0
# Evaporation        12.0
# Sunshine           12.3
# WindGustDir         SSW
# WindGustSpeed      48.0
# WindDir9am          ENE
# WindDir3pm           SW
# WindSpeed9am        6.0
# WindSpeed3pm       20.0
# Humidity9am        20.0
# Humidity3pm        13.0
# Pressure9am      1006.3
# Pressure3pm      1004.4
# Cloud9am            2.0
# Cloud3pm            5.0
# Temp9am            26.6
# Temp3pm            33.4
# RainToday            No
# RainTomorrow         No
# Name: 6049, dtype: object

# %%
dataset.WindGustDir=dataset.WindGustDir.factorize()[0]
dataset.WindDir9am=dataset.WindDir9am.factorize()[0]
dataset.WindDir3pm=dataset.WindDir3pm.factorize()[0]
dataset.RainToday=dataset.RainToday.factorize()[0]
dataset.RainTomorrow=dataset.RainTomorrow.factorize()[0]

# %%
new_dataset=dataset[dataset.RainToday==1]
new_dataset = new_dataset.append(dataset[dataset.RainToday==0].sample(n=len(new_dataset.RainToday)))
new_dataset
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustDir  \
# 6068       23.3     39.4       4.8         12.0      10.9           10
# 6071       20.3     36.0      18.0          8.2      10.5           11
# 6072       22.1     34.7       8.6          8.6      12.4           12
# 6083       24.1     41.4       1.6         12.6      12.3            6
# 6093       16.1     19.1      26.0          6.6       0.0           13
# ...         ...      ...       ...          ...       ...          ...
# 79896       7.4     15.5       0.0          2.2       5.0            4
# 102922     12.5     33.1       0.0          8.0      12.5           11
# 22153      19.3     25.2       0.0          5.4      11.2            6
# 100979     15.8     35.5       0.0          9.6      10.9            1
# 35008      13.8     26.3       0.0          4.4       9.5            7
#
#         WindGustSpeed  WindDir9am  WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 6068             59.0           5          10          19.0  ...         54.0
# 6071             94.0           2          10          13.0  ...         89.0
# 6072             50.0          10           0          11.0  ...         46.0
# 6083             39.0           8           3          17.0  ...         50.0
# 6093             54.0          13          12          28.0  ...         81.0
# ...               ...         ...         ...           ...  ...          ...
# 79896            46.0           2          13          19.0  ...         84.0
# 102922           39.0           8           3           7.0  ...         34.0
# 22153            50.0           0           6          31.0  ...         72.0
# 100979           39.0           2           6          28.0  ...         38.0
# 35008            30.0           4          13          13.0  ...         50.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 6068           14.0       1011.1       1008.5       1.0       7.0     27.0
# 6071           50.0       1008.6       1006.7       7.0       4.0     24.7
# 6072           23.0       1008.6       1008.3       2.0       6.0     28.1
# 6083           21.0       1007.0       1003.5       0.0       4.0     28.2
# 6093           93.0       1014.3       1013.2       7.0       7.0     17.1
# ...             ...          ...          ...       ...       ...      ...
# 79896          63.0       1014.3       1012.3       4.0       7.0     11.6
# 102922          9.0       1015.6       1014.3       3.0       3.0     23.3
# 22153          70.0       1018.0       1017.0       4.0       3.0     22.3
# 100979         21.0       1016.6       1013.7       0.0       3.0     24.4
# 35008          41.0       1021.9       1017.3       1.0       1.0     20.4
#
#         Temp3pm  RainToday  RainTomorrow
# 6068       37.0          1             0
# 6071       33.4          1             1
# 6072       33.2          1             0
# 6083       38.8          1             0
# 6093       17.0          1             1
# ...         ...        ...           ...
# 79896      13.9          0             0
# 102922     32.2          0             0
# 22153      23.8          0             0
# 100979     34.0          0             0
# 35008      24.6          0             0
#
# [24924 rows x 21 columns]

# %%
# split the data to features and labels 
x=new_dataset.iloc[:,:-2]
y=new_dataset.iloc[:,-2]

# %%
# scale the feature values between 0,1
min_max_preprocess =preprocessing.StandardScaler()
min_max_preprocess.fit(x)
x_norm=min_max_preprocess.transform(x)

# %%
pd.DataFrame(x_norm).hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'0'}>,
#         <AxesSubplot:title={'center':'1'}>,
#         <AxesSubplot:title={'center':'2'}>,
#         <AxesSubplot:title={'center':'3'}>],
#        [<AxesSubplot:title={'center':'4'}>,
#         <AxesSubplot:title={'center':'5'}>,
#         <AxesSubplot:title={'center':'6'}>,
#         <AxesSubplot:title={'center':'7'}>],
#        [<AxesSubplot:title={'center':'8'}>,
#         <AxesSubplot:title={'center':'9'}>,
#         <AxesSubplot:title={'center':'10'}>,
#         <AxesSubplot:title={'center':'11'}>],
#        [<AxesSubplot:title={'center':'12'}>,
#         <AxesSubplot:title={'center':'13'}>,
#         <AxesSubplot:title={'center':'14'}>,
#         <AxesSubplot:title={'center':'15'}>],
#        [<AxesSubplot:title={'center':'16'}>,
#         <AxesSubplot:title={'center':'17'}>,
#         <AxesSubplot:title={'center':'18'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.hist(y)
# Out:
# (array
activation=activation_tuner,kernel_regularizer=kernel_regularizer_tuner[0],name='D1')
        self.D1_dropout = tf.keras.layers.Dropout(0.3)
        self.D2=tf.keras.layers.Dense(units_tuner[1],activation=activation_tuner,kernel_regularizer=kernel_regularizer_tuner[1],name='D2')
        self.D2_dropout = tf.keras.layers.Dropout(0.3)
        self.D3=tf.keras.layers.Dense(units_tuner[2],activation=activation_tuner,kernel_regularizer=kernel_regularizer_tuner[2],name='D3')
        self.D3_dropout = tf.keras.layers.Dropout(0.3)
        self.D4=tf.keras.layers.Dense(units_tuner[3],activation=activation_tuner,kernel_regularizer=kernel_regularizer_tuner[3],name='D4')
        self.D4_dropout = tf.keras.layers.Dropout(0.3)
        self.D5=tf.keras.layers.Dense(units_tuner[4],activation=activation_tuner,kernel_regularizer=kernel_regularizer_tuner[4],name='D5')
        self.D5_dropout = tf.keras.layers.Dropout(0.3)
        self.out=tf.keras.layers.Dense(1,activation=tf.nn.sigmoid,name='out')
    def call(self,x ):
        x=self.D1(x)
        if self.dropout_tuner:
            x=self.D1_dropout(x)
        x=self.D2(x)
        if self.dropout_tuner:
            x=self.D2_dropout(x)
        x=self.D3(x)
        if self.dropout_tuner:
            x=self.D3_dropout(x)
        x=self.D4(x)
        if self.dropout_tuner:
            x=self.D4_dropout(x)
        x=self.D5(x)
        if self.dropout_tuner:
            x=self.D5_dropout(x)
        out = self.out(x)
        return out

# %%
def model_builder(hp):
    # define the kernel values tuner 
    units_tuner=[hp.Int('D1', min_value=8, max_value=512, step=32),
                  hp.Int('D2', min_value=8, max_value=512, step=32),
                  hp.Int('D3', min_value=8, max_value=512, step=32),
                  hp.Int('D4', min_value=8, max_value=512, step=32),
                  hp.Int('D5', min_value=8, max_value=512, step=32)]
                 
    # define the activation function tuner 
    activation_tuner = hp.Choice('activation',[0,1,2])

    # define the kernel_regularizer_tuner
    kernel_regularizer_tuner=[hp.Choice('regularizer_1',['L1','L2','L1L2']),
                              hp.Choice('regularizer_2',['L1','L2','L1L2']),
                              hp.Choice('regularizer_3',['L1','L2','L1L2']),
                              hp.Choice('regularizer_4',['L1','L2','L1L2']),
                              hp.Choice('regularizer_5',['L1','L2','L1L2']),
                              ]
    # define the dropout_tuner
    dropout_tuner= hp.Choice('dropout',[True,False])
    
    
    model = Model(
                      units_tuner=units_tuner,
                      activation_tuner=activation_tuner,
                      kernel_regularizer_tuner=kernel_regularizer_tuner,
                      dropout_tuner=dropout_tuner,
                     
                      )
    
    model.build((None,19))# build the model 
    
    # define the learning rate tuner 
    learning_rate = hp.Float("lr", min_value=1e-4, max_value=1e-2, sampling="log")
    # compile the model 
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate), loss=tf.keras.losses.BinaryCrossentropy(), metrics=["accuracy"]
    )
    return model

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=10,
                     factor=3,
                     directory='my_dir',
                     project_name='intro_to_kt')

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(train_dataset, epochs=50,validation_data=test_dataset , callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# Trial 30 Complete [00h 00m 50s]
# val_loss: 0.36308321356773376
#
# Best val_loss So Far: 0.08545342087745667
# Total elapsed time: 00h 16m 54s

# %%
a=tuner.get_best_hyperparameters()[0]
a.values
# Out:
# {'D1': 328,
#  'D2': 328,
#  'D3': 8,
#  'D4': 200,
#  'D5': 360,
#  'activation': 2,
#  'regularizer_1': 'L2',
#  'regularizer_2': 'L2',
#  'regularizer_3': 'L2',
#  'regularizer_4': 'L1L2',
#  'regularizer_5': 'L2',
#  'dropout': 1,
#  'lr': 0.0004963978725171125,
#  'tuner/epochs': 10,
#  'tuner/initial_epoch': 4,
#  'tuner/bracket': 2,
#  'tuner/round': 2,
#  'tuner/trial_id': '0012'}

# %%
best_hps

# %% [markdown]
# ## Model Evaluation

# %%
#Get optimal hyperparameters and models from the tuner
model = tuner.hypermodel.build(tuner.get_best_hyperparameters()[0])

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  D1 (Dense)                  multiple                  6560
#
#  dropout_5 (Dropout)         multiple                  0
#
#  D2 (Dense)                  multiple                  107912
#
#  dropout_6 (Dropout)         multiple                  0
#
#  D3 (Dense)                  multiple                  2632
#
#  dropout_7 (Dropout)         multiple                  0
#
#  D4 (Dense)                  multiple                  1800
#
#  dropout_8 (Dropout)         multiple                  0
#
#  D5 (Dense)                  multiple                  72360
#
#  dropout_9 (Dropout)         multiple                  0
#
#  out (Dense)                 multiple                  361
#
# =================================================================
# Total params: 191,625
# Trainable params: 191,625
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_dataset,epochs=50,validation_data=test_dataset)
# Out:
# Epoch 1/50
# 701/701 [==============================] - 9s 10ms/step - loss: 1.3735 - accuracy: 0.9088 - val_loss: 0.3267 - val_accuracy: 0.9739
# Epoch 2/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.2776 - accuracy: 0.9642 - val_loss: 0.1957 - val_accuracy: 0.9791
# Epoch 3/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1936 - accuracy: 0.9754 - val_loss: 0.1569 - val_accuracy: 0.9811
# Epoch 4/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.1591 - accuracy: 0.9786 - val_loss: 0.1287 - val_accuracy: 0.9872
# Epoch 5/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1482 - accuracy: 0.9771 - val_loss: 0.1120 - val_accuracy: 0.9888
# Epoch 6/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1317 - accuracy: 0.9811 - val_loss: 0.1260 - val_accuracy: 0.9775
# Epoch 7/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.1222 - accuracy: 0.9815 - val_loss: 0.0983 - val_accuracy: 0.9880
# Epoch 8/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1156 - accuracy: 0.9822 - val_loss: 0.0896 - val_accuracy: 0.9904
# Epoch 9/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1100 - accuracy: 0.9827 - val_loss: 0.0895 - val_accuracy: 0.9912
# Epoch 10/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1116 - accuracy: 0.9820 - val_loss: 0.1057 - val_accuracy: 0.9824
# Epoch 11/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.1029 - accuracy: 0.9841 - val_loss: 0.0882 - val_accuracy: 0.9888
# Epoch 12/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1031 - accuracy: 0.9844 - val_loss: 0.0944 - val_accuracy: 0.9872
# Epoch 13/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1036 - accuracy: 0.9840 - val_loss: 0.0782 - val_accuracy: 0.9892
# Epoch 14/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0961 - accuracy: 0.9837 - val_loss: 0.0683 - val_accuracy: 0.9960
# Epoch 15/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0957 - accuracy: 0.9840 - val_loss: 0.0721 - val_accuracy: 0.9932
# Epoch 16/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.1011 - accuracy: 0.9839 - val_loss: 0.1269 - val_accuracy: 0.9771
# Epoch 17/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1012 - accuracy: 0.9834 - val_loss: 0.0760 - val_accuracy: 0.9876
# Epoch 18/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0895 - accuracy: 0.9855 - val_loss: 0.0750 - val_accuracy: 0.9896
# Epoch 19/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0917 - accuracy: 0.9854 - val_loss: 0.0717 - val_accuracy: 0.9896
# Epoch 20/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1017 - accuracy: 0.9835 - val_loss: 0.0673 - val_accuracy: 0.9940
# Epoch 21/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0838 - accuracy: 0.9861 - val_loss: 0.0647 - val_accuracy: 0.9916
# Epoch 22/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0868 - accuracy: 0.9859 - val_loss: 0.0814 - val_accuracy: 0.9908
# Epoch 23/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0895 - accuracy: 0.9854 - val_loss: 0.0739 - val_accuracy: 0.9876
# Epoch 24/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0887 - accuracy: 0.9856 - val_loss: 0.0904 - val_accuracy: 0.9840
# Epoch 25/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0968 - accuracy: 0.9839 - val_loss: 0.0768 - val_accuracy: 0.9908
# Epoch 26/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0884 - accuracy: 0.9863 - val_loss: 0.0744 - val_accuracy: 0.9912
# Epoch 27/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0861 - accuracy: 0.9852 - val_loss: 0.0777 - val_accuracy: 0.9860
# Epoch 28/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0841 - accuracy: 0.9866 - val_loss: 0.0614 - val_accuracy: 0.9940
# Epoch 29/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0879 - accuracy: 0.9860 - val_loss: 0.0738 - val_accuracy: 0.9884
# Epoch 30/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0917 - accuracy: 0.9861 - val_loss: 0.0709 - val_accuracy: 0.9872
# Epoch 31/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0862 - accuracy: 0.9868 - val_loss: 0.0722 - val_accuracy: 0.9884
# Epoch 32/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0828 - accuracy: 0.9869 - val_loss: 0.0661 - val_accuracy: 0.9908
# Epoch 33/50
# 701/701 [==============================] - 7s 9ms/step - loss: 0.0840 - accuracy: 0.9857 - val_loss: 0.0695 - val_accuracy: 0.9896
# Epoch 34/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0898 - accuracy: 0.9863 - val_loss: 0.0626 - val_accuracy: 0.9944
# Epoch 35/50
# 701/701 [==============================] - 7s 11ms/step - loss: 0.0783 - accuracy: 0.9881 - val_loss: 0.0766 - val_accuracy: 0.9840
# Epoch 36/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0868 - accuracy: 0.9872 - val_loss: 0.0718 - val_accuracy: 0.9888
# Epoch 37/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0840 - accuracy: 0.9872 - val_loss: 0.0756 - val_accuracy: 0.9912
# Epoch 38/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0796 - accuracy: 0.9888 - val_loss: 0.0624 - val_accuracy: 0.9916
# Epoch 39/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0819 - accuracy: 0.9872 - val_loss: 0.0773 - val_accuracy: 0.9864
# Epoch 40/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0914 - accuracy: 0.9847 - val_loss: 0.0658 - val_accuracy: 0.9920
# Epoch 41/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0840 - accuracy: 0.9868 - val_loss: 0.0804 - val_accuracy: 0.9872
# Epoch 42/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0831 - accuracy: 0.9868 - val_loss: 0.0772 - val_accuracy: 0.9880
# Epoch 43/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0870 - accuracy: 0.9874 - val_loss: 0.0809 - val_accuracy: 0.9924
# Epoch 44/50
# 701/701 [==============================] - 7s 11ms/step - loss: 0.0775 - accuracy: 0.9873 - val_loss: 0.0613 - val_accuracy: 0.9928
# Epoch 45/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0812 - accuracy: 0.9878 - val_loss: 0.0730 - val_accuracy: 0.9884
# Epoch 46/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0779 - accuracy: 0.9880 - val_loss: 0.0761 - val_accuracy: 0.9928
# Epoch 47/50
# 701/701 [==============================] - 8s 11ms/step - loss: 0.0885 - accuracy: 0.9872 - val_loss: 0.0619 - val_accuracy: 0.9936
# Epoch 48/50
# 701/701 [==============================] - 7s 10ms/step - loss: 0.0720 - accuracy: 0.9889 - val_loss: 0.0622 - val_accuracy: 0.9920
# Epoch 49/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1060 - accuracy: 0.9831 - val_loss: 0.1271 - val_accuracy: 0.9856
# Epoch 50/50
# 701/701 [==============================] - 6s 9ms/step - loss: 0.0821 - accuracy: 0.9886 - val_loss: 0.0767 - val_accuracy: 0.9860

# %%
pd.DataFrame(model.history.history).plot()
# Out:
# <AxesSubplot:>

# %%
preds=np.array([])
ys=np.array([])
for x,y in tqdm.tqdm(test_dataset):
    pred = model.predict(x)
    preds=np.append(preds,pred)
  
    ys=np.append(ys,y)
# Out:
#   0%|          | 0/78 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 165ms/step
#   1%|▏         | 1/78 [00:00<00:19,  3.87it/s]
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
#   4%|▍         | 3/78 [00:00<00:09,  7.89it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
#   6%|▋         | 5/78 [00:00<00:07,  9.68it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#   9%|▉         | 7/78 [00:00<00:06, 10.74it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  12%|█▏        | 9/78 [00:00<00:05, 11.52it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 31ms/step
#  14%|█▍        | 11/78 [00:01<00:05, 11.94it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  17%|█▋        | 13/78 [00:01<00:05, 12.24it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
#  19%|█▉        | 15/78 [00:01<00:05, 12.54it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  22%|██▏       | 17/78 [00:01<00:04, 12.96it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
#  24%|██▍       | 19/78 [00:01<00:04, 12.58it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  27%|██▋       | 21/78 [00:01<00:04, 13.02it/s]
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
#  29%|██▉       | 23/78 [00:01<00:04, 12.75it/s]
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
#  32%|███▏      | 25/78 [00:02<00:04, 12.48it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  35%|███▍      | 27/78 [00:02<00:04, 12.66it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  37%|███▋      | 29/78 [00:02<00:03, 13.20it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
#  40%|███▉      | 31/78 [00:02<00:03, 13.14it/s]
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
#  42%|████▏     | 33/78 [00:02<00:03, 13.84it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  45%|████▍     | 35/78 [00:02<00:03, 13.61it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  47%|████▋     | 37/78 [00:03<00:03, 13.65it/s]
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
#  50%|█████     | 39/78 [00:03<00:02, 13.54it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
#  53%|█████▎    | 41/78 [00:03<00:02, 13.94it/s]
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 21ms/step
#  55%|█████▌    | 43/78 [00:03<00:02, 14.19it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
#  58%|█████▊    | 45/78 [00:03<00:02, 13.84it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
#  60%|██████    | 47/78 [00:03<00:02, 13.39it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
#  63%|██████▎   | 49/78 [00:03<00:02, 13.62it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  65%|██████▌   | 51/78 [00:04<00:01, 13.93it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
#  68%|██████▊   | 53/78 [00:04<00:01, 13.80it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
#  71%|███████   | 55/78 [00:04<00:01, 13.63it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  73%|███████▎  | 57/78 [00:04<00:01, 13.85it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  76%|███████▌  | 59/78 [00:04<00:01, 13.66it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
#  78%|███████▊  | 61/78 [00:04<00:01, 13.86it/s]
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
#  81%|████████  | 63/78 [00:04<00:01, 13.59it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
#  83%|████████▎ | 65/78 [00:05<00:00, 13.83it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 28ms/step
#  86%|████████▌ | 67/78 [00:05<00:00, 13.77it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
#  88%|████████▊ | 69/78 [00:05<00:00, 14.08it/s]
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
#  91%|█████████ | 71/78 [00:05<00:00, 14.49it/s]
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
#  94%|█████████▎| 73/78 [00:05<00:00, 13.69it/s]
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
#  96%|█████████▌| 75/78 [00:05<00:00, 13.56it/s]
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
#  99%|█████████▊| 77/78 [00:05<00:00, 13.71it/s]
# 1/1 [==============================] - 0s 95ms/step
# 100%|██████████| 78/78 [00:06<00:00, 12.86it/s]

# %%
 preds = preds>0.5
 preds=preds.astype(int)

# %%
preds.shape
# Out:
# (2493,)

# %%
accuracy_score=metrics.accuracy_score(y_true=ys,y_pred=preds)
precision_score=metrics.precision_score(ys,preds,average='weighted')
recall_score=metrics.recall_score(ys,preds,average='weighted')
f1_score=metrics.f1_score(ys,preds,average='weighted')
confion_metrix=metrics.confusion_matrix(ys,preds)
print('accuracy_score:',accuracy_score)
print('precision_score:',precision_score)
print('recall_score:',recall_score)
print('f1_score:',f1_score)
sn.heatmap(confion_metrix,annot=True,)
# Out:
# accuracy_score: 0.9859606899318091
# precision_score: 0.9859860656456128
# recall_score: 0.9859606899318091
# f1_score: 0.9859605272877598
# <AxesSubplot:>
